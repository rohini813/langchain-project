# %%
# !pip install -q langchain transformers

# %%
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Create free model
pipe = pipeline("text-generation", model="gpt2")

llm = HuggingFacePipeline(pipeline=pipe)

# Run
result = llm.invoke("Explain AI in one line")

print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1584/276380926.py in <cell line: 0>()
# ----> 1 from langchain.llms import HuggingFacePipeline
#       2 from transformers import pipeline
#       3
#       4 # Create free model
#       5 pipe = pipeline("text-generation", model="gpt2")
#
# ModuleNotFoundError: No module named 'langchain.llms'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain langchain-community transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.1/515.1 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

# Create free model
pipe = pipeline("text-generation", model="gpt2")

llm = HuggingFacePipeline(pipeline=pipe)

# Run
result = llm.invoke("Explain AI in one line")

print(result)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ...

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="gpt2",
    max_new_tokens=30
)

llm = HuggingFacePipeline(pipeline=pipe)

result = llm.invoke("Explain AI in one line:")

print(result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain AI in one line:
#
# ...

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple words"
)

print(prompt.format(topic="Artificial Intelligence"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1584/3279276497.py in <cell line: 0>()
# ----> 1 from langchain.prompts import PromptTemplate
#       2
#       3 prompt = PromptTemplate(
#       4     input_variables=["topic"],
#       5     template="Explain {topic} in simple words"
#
# ModuleNotFoundError: No module named 'langchain.prompts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple words"
)

print(prompt.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple words

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "Machine Learning"})

print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Machine Learning in simple words, words that are easy to convey and simple to learn.
#
# As an advanced tool that can be used to create simple phrases and sentences with little

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

memory = ConversationBufferMemory()

conversation = ConversationChain(
    llm=llm,
    memory=memory
)

print(conversation.run("Hi, my name is Shyam"))
print(conversation.run("What is my name?"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1584/2378814656.py in <cell line: 0>()
# ----> 1 from langchain.memory import ConversationBufferMemory
#       2 from langchain.chains import ConversationChain
#       3
#       4 memory = ConversationBufferMemory()
#       5
#
# ModuleNotFoundError: No module named 'langchain.memory'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage

# %%
# Simple memory simulation (works perfectly for your assignment)

chat_history = []

def chat(user_input):
    chat_history.append("User: " + user_input)

    # Combine history
    context = "\n".join(chat_history)

    response = llm.invoke(context)

    chat_history.append("AI: " + response)

    return response

# Test
print(chat("Hi, my name is Shyam"))
print(chat("What is my name?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# User: Hi, my name is Shyamant. I'm a small indie game developer, an expert in indie games, and I have worked on games for over 4 years. I'm a
# User: Hi, my name is Shyam
# AI: User: Hi, my name is Shyamant. I'm a small indie game developer, an expert in indie games, and I have worked on games for over 4 years. I'm a
# ...

# %%
chat_history = []

def chat(user_input):
    chat_history.append(f"User: {user_input}")

    context = "\n".join(chat_history) + "\nAI:"

    response = llm.invoke(context)

    # Clean output (take only last part)
    response = response.split("AI:")[-1].strip()

    chat_history.append(f"AI: {response}")

    return response

print(chat("Hi, my name is Shyam"))
print(chat("What is my name?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# My Name
# My Name

# %% [markdown]
# # Deep Technical Blog on LangChain
#
# This notebook demonstrates core components of LangChain including LLMs, Prompt Templates, Chains, Memory, and Agents using Python.

# %% [markdown]
# ## Introduction to LangChain
#
# LangChain is a framework used to build applications powered by Large Language Models (LLMs). It helps developers connect LLMs with external data, tools, and workflows.
#
# It solves problems like:
# - Prompt management
# - Chaining multiple operations
# - Adding memory to conversations
# - Integrating tools and APIs# New Section

# %% [markdown]
# Install

# %%
# !pip install -q langchain langchain-community transformers

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

pipe = pipeline("text-generation", model="gpt2", max_new_tokens=30)
llm = HuggingFacePipeline(pipeline=pipe)

print(llm.invoke("Explain AI in one line"))

# %% [markdown]
# ## Prompt Templates
#
# Prompt templates allow dynamic input to LLMs.# New Section

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple words"
)

print(prompt.format(topic="Artificial Intelligence"))

# %% [markdown]
# ## Chains
#
# Chains connect multiple components like prompt and LLM.# New Section

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt | llm | StrOutputParser()

print(chain.invoke({"topic": "Machine Learning"}))

# %% [markdown]
# ## Memory
#
# Memory allows the model to remember past interactions.# New Section

# %%
chat_history = []

def chat(user_input):
    chat_history.append(f"User: {user_input}")
    context = "\n".join(chat_history) + "\nAI:"
    response = llm.invoke(context)
    response = response.split("AI:")[-1].strip()
    chat_history.append(f"AI: {response}")
    return response

print(chat("Hi, my name is Shyam"))
print(chat("What is my name?"))

# %% [markdown]
# ## Agents
#
# Agents decide whether to use LLM or tools.# New Section

# %%
def simple_agent(query):
    if "calculate" in query:
        return "Using calculator tool"
    else:
        return llm.invoke(query)

print(simple_agent("Explain AI"))

# %% [markdown]
# ## Real World Use Cases
#
# 1. Chatbots with memory
# 2. AI assistants
# 3. Document question answering systems# New Section

# %% [markdown]
# ## Advantages
# - Modular design
# - Easy to build AI apps
#
# ## Limitations
# - Debugging complexity
# - Depends on model quality

# %% [markdown]
# ## Conclusion
#
# LangChain simplifies building LLM applications. It provides modular components for building scalable AI systems.
